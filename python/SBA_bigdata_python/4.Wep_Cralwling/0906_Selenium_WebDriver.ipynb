# %% [markdown]
# # Selenium 개요
#
# - BeautifulSopu 패키지만을 사용하여 크롤링을 할 경우, 모든 웹페이지의 데이터들을 가져오는 것은 아니다.
# - 예를들어, 비동기적으로 뒤늦게 웹페이지의 정보를 업데이트하는 경우와 로그인이나 특정권한을 요구하는 웹페이지의 경우가 그럴것이다.
# - 이때 필요로 하는 패키지가 바로 셀레늄(Selenium)이며, 별도의 webdriver라는 API를 통해 운영체제에 설치된 브라우저를 제어할 수 있다.
# - 즉, 셀레늄을 사용하면 웹페이지상에서 눈에 보이는 모든 데이터를 가져올 수 있다.

# %% [markdown]
# ## Selenium 환경 설정 방법
#
# ### 1. Selenium Package Install
# Anaconda Prompt 에서 pip install selenium 실행
#
# ### 2. Webdriver Down & Install
# - 가장 보편적으로 많이 사용하는 크롬 웹드라이브를 다운받아서 설치한다.
# - 아래 사이트에서 OS에 맞는 웹드라이브를 다운받아 압축을 풀어 driver 폴더에 복사해둔다.
# - 크롬 웹드라이브 다운 : https://chromedriver.storage.googleapis.com/index.html?path=2.35/

# %%
from bs4 import BeautifulSoup
from selenium import webdriver
from IPython.display import Image

import re

# %%
# 웹드라이브로 크롬브라우즈 띄운다.
driver_path = "driver/chromedriver.exe"
driver = webdriver.Chrome(executable_path=driver_path)

# %%
url_page = 'http://www.seleniumhq.org/projects/webdriver/'
driver.get(url_page)  # 페이지 뛰우기

# %%
driver.find_element_by_css_selector('#menu_download > a').click()

#driver.fine_element_by_xpath

# %%
capture_img = './images/seleniumhq_download.png'
driver.save_screenshot(capture_img)
Image(capture_img)

# find_element_by_xpath: xml기반
#

# %% [markdown]
# - 네이버 크롤링

# %%
# 네이버 크롤링
url_page = 'https://www.naver.com'
driver.get(url_page)

# %%
# XQury
driver.find_element_by_xpath('//*[@id="PM_ID_serviceNavi"]/li[6]/a').click()

# jQuery
# driver.find_element_by_css_selector('#PM_ID_serviceNavi > li:nth-child(6) > a').click()

# %%
# 평점&리뷰 1등 페이지로 이동
driver.find_element_by_css_selector('#review1 > div > a').click()

# %%
# 리뷰 클릭
driver.find_element_by_css_selector('#movieEndTabMenu > li:nth-child(6) > a').click()

# %%
current_url = driver.current_url
current_url
# Out:
# 'https://movie.naver.com/movie/bi/mi/review.nhn?code=167560'

# %%
# pattern = re.compile("[\d+,?]+")
pattern = re.compile("\d{6}")
result = pattern.findall(current_url)
code = result[0] if len(result)>0 else ''
code
# Out:
# '167560'

# %%
review_url = current_url.replace(code, '{}')
review_url
# Out:
# 'https://movie.naver.com/movie/bi/mi/review.nhn?code={}'

# %% [markdown]
# - 영화 리뷰 페이지로 바로 이동

# %%
# 영화제목 검색키 입력
movie_title = '봉오동 전투'
movie_title = '알라딘'
driver.find_element_by_css_selector('#ipt_tx_srch').send_keys(movie_title)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-26-9f06b353c8b4> in <module>
#       2 movie_title = '봉오동 전투'
#       3 movie_title = '알라딘'
# ----> 4 driver.find_element_by_css_selector('#ipt_tx_srch').send_keys(movie_title)
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#ipt_tx_srch"}
#   (Session info: chrome=76.0.3809.132)

# %%
# 검색 클릭
driver.find_element_by_css_selector('#jSearchArea > div > button').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-27-a5d21254f070> in <module>
#       1 # 검색 클릭
# ----> 2 driver.find_element_by_css_selector('#jSearchArea > div > button').click()
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#jSearchArea > div > button"}
#   (Session info: chrome=76.0.3809.132)

# %%
# 검색 첫번째 페이지로 이동
driver.find_element_by_css_selector('#old_content > ul:nth-child(4) > li:nth-child(1) > dl > dt > a').click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-28-ebb8883201d1> in <module>
#       1 # 검색 첫번째 페이지로 이동
# ----> 2 driver.find_element_by_css_selector('#old_content > ul:nth-child(4) > li:nth-child(1) > dl > dt > a').click()
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#     980     def find_elements(self, by=By.ID, value=None):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"#old_content > ul:nth-child(4) > li:nth-child(1) > dl > dt > a"}
#   (Session info: chrome=76.0.3809.132)

# %%
# 페이지 BeautifulSoup 객체로 가져온다
html = driver.page_source
soup = BeautifulSoup(html, "lxml")

# %%
soup.title

# %%
current_url = driver.current_url
current_url
# Out:
# 'data:,'

# %%
pattern = re.compile("\d{6}")
result = pattern.findall(current_url)
code = result[0] if len(result)>0 else ''
code
# Out:
# ''

# %%
'163788'
# 영화메인페이지 캡처후 저장
capture_img = './images/naver_movie_{code}.png'.format(code=code)
driver.save_screenshot(capture_img)
Image(capture_img)

# %%
# 리뷰페이지로 바로 이동
url_page = review_url.format(code)
driver.get(url_page)

# %%
html = driver.page_source
soup = BeautifulSoup(html, "lxml")
soup.title
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-39-62af9474ff4c> in <module>
# ----> 1 html = driver.page_source
#       2 soup = BeautifulSoup(html, "lxml")
#       3 soup.title
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\Python\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=76.0.3809.132)

# %%
movie_title = soup.title.get_text().split(':')[0].strip()
movie_title
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-0c43e62d2f4f> in <module>
# ----> 1 movie_title = soup.title.get_text().split(':')[0].strip()
#       2 movie_title
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
review_cnt = soup.find("span","cnt")
review_cnt

# %%
review_cnt2 = review_cnt.find("em").get_text()
review_cnt2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-b96a8587d9cf> in <module>
# ----> 1 review_cnt2 = review_cnt.find("em").get_text()
#       2 review_cnt2
#
# AttributeError: 'NoneType' object has no attribute 'find'

# %%
review_cnt_total = int(review_cnt2.replace(',', ''))
review_cnt_total

# %%
last_page = review_cnt_total//10 + 1
last_page

# %%
'영화 "{}"의 리뷰수는 총 {}건이며, 마지막 페이지는 {} 입니다.'.format(movie_title, review_cnt_total, last_page)

# %%
# 리뷰 마지막 페이지로 이동
url_page = 'https://movie.naver.com/movie/bi/mi/review.nhn?code={}&page={}'.format(code, last_page)
driver.get(url_page)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-cbb44e5a18ca> in <module>
#       1 # 리뷰 마지막 페이지로 이동
# ----> 2 url_page = 'https://movie.naver.com/movie/bi/mi/review.nhn?code={}&page={}'.format(code, last_page)
#       3 driver.get(url_page)
#
# NameError: name 'last_page' is not defined
